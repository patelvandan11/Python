# %% [markdown]
# # box plot

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
var=pd.read_csv("tips.csv")
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=var)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=var)
plt.show()

# %%
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=var,hue="time")
plt.show()

# %%
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=var,hue="sex")
plt.show()

# %%
sns.set(style="whitegrid")
# sns.boxplot(x="day",y="total_bill",data=var,hue="sex",order=["Fri","Sun","Thur","Sat"])
# sns.boxplot(x="day",y="total_bill",data=var,hue="sex",order=["Fri","Sun","Thur","Sat"],showmeans=True)
# sns.boxplot(x="day",y="total_bill",data=var,hue="sex",order=["Fri","Sun","Thur","Sat"],showmeans=True,meanprops={"marker":"*","markeredgecolor":"m"})
# sns.boxplot(x="day",y="total_bill",data=var,hue="sex",order=["Fri","Sun","Thur","Sat"],showmeans=True,meanprops={"marker":"*","markeredgecolor":"m"},linewidth=3)
# sns.boxplot(x="day",y="total_bill",data=var,hue="sex",order=["Fri","Sun","Thur","Sat"],showmeans=True,meanprops={"marker":"*","markeredgecolor":"m"},linewidth=3,palette="icefire")
sns.boxplot(x="day",y="total_bill",data=var,hue="sex",order=["Fri","Sun","Thur","Sat"],showmeans=True,meanprops={"marker":"*","markeredgecolor":"m"},linewidth=3,palette="icefire")
plt.show()

# %%
sns.boxplot(x="day",y="total_bill",data=var,hue="sex",order=["Fri","Sun","Thur","Sat"],showmeans=True,meanprops={"marker":"*","markeredgecolor":"m"},linewidth=3,palette="icefire",orient="v")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="total_bill",y="day",data=var,hue="sex",order=["Fri","Sun","Thur","Sat"],showmeans=True,meanprops={"marker":"*","markeredgecolor":"m"},linewidth=3,palette="icefire",orient="h")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.boxplot(data=var,showmeans=True,meanprops={"marker":"*","markeredgecolor":"m"},linewidth=3,palette="icefire",orient="h")
# Out:
# <Axes: >

# %%
sns.boxplot(x="total_bill",data=var)
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(y="total_bill",data=var)
# Out:
# <Axes: ylabel='total_bill'>
